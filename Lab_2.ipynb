# %%
from qiskit import qiskit, QuantumCircuit
#Create a quantum circuit with 1 qubit and 1 classical bit.
qc = QuantumCircuit(1,1)
#Apply a NOT gate on qubit 0. 
# qc.x(0)
#Apply a Hadamard gate on qubit 0.
qc.h(0)
#Measure qubit 0  to classical bit 0.
qc.measure(0,0)
job = qiskit.execute(qc,qiskit.BasicAer.get_backend('qasm_simulator'))
print(job.result().get_counts())
# Out:
# {'0': 499, '1': 525}

# %%
qc.draw()

# %%
print(qc)
# Out:
#    ┌───┐┌─┐
# q: ┤ H ├┤M├
#    └───┘└╥┘
# c: ══════╩═

# %%
# histogram 
from qiskit.visualization import plot_histogram
result = job.result().get_counts()
plot_histogram(result)

# %%
result3 = [result1,result2]
legend6 = ['First execution', 'Second execution']
title6 = 'New histogram'
figsize6 = (10,10)
color6 = ['crimson', 'midnightblue']
plot_histogram(result3, legend = legend6, title = title6, figsize = figsize6, color=color6)

# %%
from qiskit import qiskit, QuantumCircuit
#Create a quantum circuit with 1 qubit and 1 classical bit.
qc = QuantumCircuit(1,1)
#Apply a NOT gate on qubit 0. 
# qc.x(0)
#Apply a Hadamard gate on qubit 0.
qc.h(0)
#Measure qubit 0  to classical bit 0.
qc.measure(0,0)
job = qiskit.execute(qc,qiskit.BasicAer.get_backend('qasm_simulator'))
resutl1 = job.result().get_counts()

# %%
from qiskit import qiskit, QuantumCircuit
#Create a quantum circuit with 1 qubit and 1 classical bit.
qc = QuantumCircuit(1,1)
#Apply a NOT gate on qubit 0. 
# qc.x(0)
#Apply a Hadamard gate on qubit 0.
qc.h(0)
#Measure qubit 0  to classical bit 0.
qc.measure(0,0)
job = qiskit.execute(qc,qiskit.BasicAer.get_backend('qasm_simulator'))
resutl2 = job.result().get_counts()

# %%
result3 = [result1,result2]
legend6 = ['First execution', 'Second execution']
title6 = 'New histogram'
figsize6 = (10,10)
color6 = ['crimson', 'midnightblue']
plot_histogram(result3, legend = legend6, title = title6, figsize = figsize6, color=color6)

# %%
#saving file
plot_histogram(result3, filename = 'new_hist.png')
hist = plot_histogram(result3)
hist.savefig('new_hist.png')

# %%
#plot statecity
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_state_city
qc = QuantumCircuit(2)
qc.h(1)


#plot  using a Statevector
state = Statevector(qc)
plot_state_city(state)

# %%
qc.draw()
